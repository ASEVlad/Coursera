# %%
import json
import bz2
import numpy as np
import pandas
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingClassifier
import datetime
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
features = pandas.read_csv('D:/Prog/ML/Coursera/Yandex rus/last task/features.csv', index_col='match_id', dtype=np.float32)

features.head()
# Out:
#             start_time  lobby_type  r1_hero  r1_level   r1_xp  r1_gold  r1_lh  \
# match_id
# 0.0       1.430199e+09         7.0     11.0       5.0  2098.0   1489.0   20.0
# 1.0       1.430220e+09         0.0     42.0       4.0  1188.0   1033.0    9.0
# 2.0       1.430227e+09         7.0     33.0       4.0  1319.0   1270.0   22.0
# 3.0       1.430264e+09         1.0     29.0       4.0  1779.0   1056.0   14.0
# 4.0       1.430282e+09         7.0     13.0       4.0  1431.0   1090.0    8.0
#
#           r1_kills  r1_deaths  r1_items          ...           \
# match_id                                         ...
# 0.0            0.0        0.0       7.0          ...
# 1.0            0.0        1.0      12.0          ...
# 2.0            0.0        0.0      12.0          ...
# 3.0            0.0        0.0       5.0          ...
# 4.0            1.0        0.0       8.0          ...
#
#           dire_boots_count  dire_ward_observer_count  dire_ward_sentry_count  \
# match_id
# ...

# %%
features = features.drop(['duration', 'tower_status_radiant', 'tower_status_dire', 'barracks_status_radiant', 'barracks_status_dire'], axis=1)
features = features.fillna(features.mean())

# %%
y = features['radiant_win']
X = features.drop('radiant_win', axis=1)

# %%
scores = list()
k_fold = KFold(n_splits=5, shuffle=True)
for n_estimators in range(10,11,10):
    clf = GradientBoostingClassifier(n_estimators=n_estimators, verbose=True)
    clf.fit(X, y)
    score = cross_val_score(clf, X, y, scoring='roc_auc', cv=k_fold)
    scores.append(score.mean())
scores
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.3786           10.61s
#          2           1.3732            8.63s
#          3           1.3682            7.51s
#          4           1.3636            6.40s
#          5           1.3589            5.09s
#          6           1.3547            4.01s
#          7           1.3502            2.92s
#          8           1.3461            1.90s
#          9           1.3423            0.94s
#         10           1.3385            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.3789            6.11s
#          2           1.3734            5.40s
#          3           1.3684            4.75s
#          4           1.3640            4.08s
#          5           1.3592            3.34s
#          6           1.3550            2.70s
#          7           1.3512            2.02s
#          8           1.3471            1.33s
#          9           1.3431            0.66s
# ...

# %%
param_grid  = {'C': np.logspace(-3, -1, 10)}
clf_grid = GridSearchCV(LogisticRegression(random_state=241), param_grid, cv=k_fold, verbose=True, scoring='roc_auc')
clf_grid.fit(X, y)

lr=LogisticRegression(n_jobs=-1,random_state=241,**clf_grid.best_params_)
lr.fit(X, y)
score = cross_val_score(clf, X, y, scoring='roc_auc', cv=k_fold)
print(score.mean())
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# D:\Prog\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\Prog\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\Prog\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\Prog\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
data_full_norm = pandas.DataFrame(data=StandardScaler().fit_transform(features))
y = features['radiant_win']
X = features.drop('radiant_win', axis=1)
# Out:
# D:\Prog\Anaconda\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype float32 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# D:\Prog\Anaconda\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype float32 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
param_grid  = {'C': np.logspace(-3, -1, 10)}
clf_grid = GridSearchCV(LogisticRegression(random_state=241), param_grid, cv=k_fold, verbose=True, scoring='roc_auc')
clf_grid.fit(X, y)

lr=LogisticRegression(n_jobs=-1,random_state=241,**clf_grid.best_params_)
lr.fit(X, y)
score = cross_val_score(clf, X, y, scoring='roc_auc', cv=k_fold)
print(score.mean())
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# D:\Prog\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\Prog\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\Prog\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\Prog\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
features = features.drop(['lobby_type', 'r1_hero', 'r2_hero', 'r3_hero', 'r4_hero', 'r5_hero', 'd1_hero', 'd2_hero', 'd3_hero', 'd4_hero', 'd5_hero'], axis=1)
y = features['radiant_win']
X = features.drop('radiant_win', axis=1)

param_grid  = {'C': np.logspace(-3, -1, 10)}
clf_grid = GridSearchCV(LogisticRegression(random_state=241), param_grid, cv=k_fold, verbose=True, scoring='roc_auc')
clf_grid.fit(X, y)

lr=LogisticRegression(n_jobs=-1,random_state=241,**clf_grid.best_params_)
lr.fit(X, y)
score = cross_val_score(clf, X, y, scoring='roc_auc', cv=k_fold)
print(score.mean())
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# D:\Prog\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\Prog\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\Prog\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\Prog\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...
